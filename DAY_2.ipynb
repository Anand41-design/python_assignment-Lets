# %%
Int And Float values
a=12
b=18.1

Boolean Values 
x ="Hello"
y = 0

LIST:
list_1=list()
list_1.append(1)
list_1.append(1)
list_1.append(3)
list_1.append(5)
list_1.append(11)

# %%
list_1
# Out:
# [1, 1, 3, 5, 11]

# %%
Q=tuple()

# %%
Q
# Out:
# ()

# %%
Q=('9','8','7','6','5','5','4')

# %%
Q
# Out:
# ('9', '8', '7', '6', '5', '5', '4')

# %%
type(Q)
# Out:
# tuple

# %%
new=dict()

# %%
new
# Out:
# {}

# %%
new['name']='prakash'
new['age']='20'
new['country']='India'

# %%
new
# Out:
# {'name': 'prakash', 'age': '20', 'country': 'India'}

# %%
#print 

print(a,b,x,y)
# Out:
# 12 18.1 Hello 0

# %%
print("Int var is %s and FLoat var is %s and Bool is %s %s"%(a,b,x,y))
# Out:
# Int var is 12 and FLoat var is 18.1 and Bool is Hello 0

# %%
print("List is {} and Tuple is {} ".format(list_1,Q))
# Out:
# List is [1, 1, 3, 5, 11] and Tuple is ('9', '8', '7', '6', '5', '5', '4')

# %%
print(f"Tuple is {Q} and Dict is {new} and list is {list_1}")
# Out:
# Tuple is ('9', '8', '7', '6', '5', '5', '4') and Dict is {'name': 'prakash', 'age': '20', 'country': 'India'} and list is [1, 1, 3, 5, 11]

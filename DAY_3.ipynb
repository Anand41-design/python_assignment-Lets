# %%
new=list()

# %%
type(new)
# Out:
# list

# %%
name=input("Enter the Name: ")
age=input("Enter the Age: ")
address=input("Enter the Adress: ")
qualification=input("Enter the Qualification: ")
Salary=(input("Enter the Salary: "))
Family_members=(input("Enter the family Members: "))
# Out:
# Enter the Name: Bala
# Enter the Age: 23
# Enter the Adress: Chennai
# Enter the Qualification: B.E-ECE
# Enter the Salary: 23,000
# Enter the family Members: Anand,Raj,Lakshmi

# %%
new=list()
new=(name,age,address,qualification,Salary,Family_members)
new
# Out:
# ('Bala', '23', 'Chennai', 'B.E-ECE', '23,000', 'Anand,Raj,Lakshmi')

# %%
print(f'The name is {name} and age is {age} , lives in {address}, Qualification is {qualification} and get Salary {Salary} The members of family are {Family_members}')
# Out:
# The name is Bala and age is 23 , lives in Chennai, Qualification is B.E-ECE and get Salary 23,000 The members of family are Anand,Raj,Lakshmi
